# %% [markdown]
# # Reto 2 - Sistema RAG usando IA Generativa para el diseño de la Arquitectura
# ## 1. Instalación de dependencias y inicialización del entorno para generar las respuestas del LLM

# %%
# instalamos langchain
# !pip install langchain_openai -q

# %%
# Cargamos el TOKEN de OpenAI para poder ejecutar prompts
import os
from dotenv import load_dotenv

load_dotenv()

if not os.getenv("OPENAI_API_KEY"):
    print("⚠️  OPENAI_API_KEY no encontrada. Configura tu API key en archivo .env")
else:
    print("✅ OpenAI API Key configurada")
# Out:
# ✅ OpenAI API Key configurada

# %%
# Importamos las librerias para ejecutar los prompts
from langchain_openai import ChatOpenAI
# Inicializamos el modelo LangChain OpenAI
# Seleccionamos la temperatura de 0 para mantener el modelo lo mas
# deterministico posible
llm = ChatOpenAI(
    model="gpt-5",
    temperature=0
)

# %% [markdown]
# ## 2. Fewshot con metodología CoT y CREATE para la creación de un promppt mas especifico y con los requerimientos especificos para el diseño del arquitectura del software

# %%
# Few-shot con Cadena de Pensamiento utilizando tecnología C.R.E.A.T.E.
few_shot_cot_create = """
<instruction>
Actúa como un arquitecto senior de software de Python especializado con mas de 10 años de experiencia en sistemas CRUD, 
y amplia experiencia en implementaciones en Dockers Compose.
</instruction>

<context>
Estoy trabajando en la implementación de un sistema CRUD para la gestion de la identidad digital de usuarios
optimizando el código, la arquitectura del software y los procesos para mejorar el performance, la seguridad y
la mantenibilidad de la app.
</context>

<requirements>
Crear la arquitectura de la app para la gestion de un sistema CRUD que:
- Utilice la tecnica de Chain of thought para diseñar la arquitectura del sistema.
- Incluya los siguientes componentes: backend, frontend, base de datos y contenerizacion basica.
- Implemente funcionalidades core de autneticación, gestion de usuarios, y una caracteristica de analisis urbano
como accidentes o inicidentes de trafico.
- Defina una arquitectura simplificada pero funcional.
</requirements>

<specifications>
- Debe de usar API Rest para el backend.
- Debe de usar la tecnica de Chain of thought para diseñar la arquitectura del sistema.
- Debe usar SQlite como base de datos.
- Debe usar Streamlit para la creación del frontend.
- Debe de tener una arquitectura simplificada pero funcional.
- Debe de estar contenerizada con Dockers Compose.
- Debe de incluir las dependencias necesarias para ejecutar el código.
- Debe de incluir ejemplos de la arquitectura.
- Debe de describir el proceso de diseño en pasos enumerados.
</specifications>

<artifacts>
Genera en orden especifico:
1. La estructura basica de la app.
2. Los pasos necesarios para la implementación del backend.
3. Los pasos necesarios para la implementación de la base de datos.
4. Los pasos necesarios para la implemenetación del frontend.
5. Los pasos necesariso para la contenerizacion.
6. Los puntos a favor y en contra de la arquitectura seleccionada.
7. Los puntos de mejora de la arquitectura seleccionada.
8. Ejemplo de cada uno de los archivos generados en la arquitectura propuesta.
</artifacts>

"""

# %%
# Ejecutamos el prompt e imprimimos el resultado
few_shot_cot_create_response = llm.invoke(few_shot_cot_create)
print(few_shot_cot_create_response.content)
# Out:
# A continuación encontrarás una propuesta de arquitectura simplificada pero funcional para un sistema CRUD de gestión de identidad digital con autenticación, gestión de usuarios y una característica de análisis urbano de incidentes de tráfico, usando FastAPI (REST), SQLite, Streamlit y Docker Compose.
#
# 1) Estructura básica de la app
# - Descripción general
#   - backend: API REST con FastAPI, autenticación JWT, CRUD de usuarios e incidentes, endpoint de analítica básica.
#   - base de datos: SQLite con SQLAlchemy. Persistencia en volumen de Docker.
#   - frontend: Streamlit consumiendo la API para login, CRUD de incidentes y visualización analítica y geográfica.
#   - contenerización: 2 servicios (backend y frontend) orquestados con Docker Compose.
#
# - Árbol de directorios
#   .
#   ├── backend
#   │   ├── app
#   │   │   ├── __init__.py
#   │   │   ├── main.py
#   │   │   ├── core
#   │   │   │   ├── __init__.py
#   │   │   │   └── config.py
#   │   │   ├── db
#   │   │   │   ├── __init__.py
#   │   │   │   ├── models.py
#   │   │   │   └── session.py
#   │   │   ├── schemas
#   │   │   │   ├── __init__.py
#   │   │   │   ├── user.py
#   │   │   │   └── incident.py
#   │   │   └── api
#   │   │       ├── __init__.py
#   │   │       ├── deps.py
#   │   │       └── v1
#   │   │           ├── __init__.py
#   │   │           ├── api.py
#   │   │           └── endpoints
#   │   │               ├── auth.py
#   │   │               ├── users.py
#   │   │               ├── incidents.py
#   │   │               └── analytics.py
#   │   ├── requirements.txt
#   │   └── Dockerfile
#   ├── frontend
#   │   ├── app.py
#   │   ├── requirements.txt
#   │   └── Dockerfile
#   ├── docker-compose.yml
#   ├── .env.example
#   └── README.md (opcional)
#
# 2) Pasos necesarios para la implementación del backend
# - Proceso de diseño (resumen de razonamiento en pasos)
#   1. Objetivos: API REST simple, segura y extensible con autenticación JWT, CRUD de usuarios e incidentes y un endpoint de analítica.
#   2. Restricciones: SQLite (persistencia local), minimizar dependencias y complejidad de despliegue, separar responsabilidades por módulos.
#   3. Decisiones clave:
#      - FastAPI por rendimiento, tipado y documentación automática.
#      - SQLAlchemy 2.x con SQLite y PRAGMAs para mejor concurrencia (WAL).
#      - JWT con HS256 para simplicidad (PyJWT) y Passlib para hashing bcrypt.
#      - Capas: modelos, esquemas (Pydantic), endpoints, dependencias de seguridad.
#   4. Trade-offs: SQLite vs RDBMS completo (simplicidad vs alta concurrencia), JWT vs sesión de servidor (stateless vs revocación).
#   5. Diseño de entidades: User, Incident; relaciones y esquemas de entrada/salida.
#   6. Seguridad: password hashing, token expirable, scopes de superusuario para administración.
#   7. Observabilidad mínima: endpoint /health.
#   8. CORS para permitir frontend separado.
#   9. Contenedores separados para escalar independientemente front y back.
#
# - Implementación paso a paso
#   1. Crear entorno y dependencias en backend/requirements.txt.
#   2. Configuración (core/config.py): variables de entorno, secretos y URL de BD.
#   3. Sesión y motor de BD (db/session.py): engine, SessionLocal, Base, PRAGMA WAL.
#   4. Modelos (db/models.py): User e Incident.
#   5. Esquemas (schemas/*.py): Pydantic para validación IO.
#   6. Seguridad (core/security.py): hashing y generación de JWT.
#   7. Dependencias (api/deps.py): get_db, current_user, superuser.
#   8. Rutas:
#      - auth.py: registro y login.
#      - users.py: CRUD de usuarios, /users/me.
#      - incidents.py: CRUD de incidentes.
#      - analytics.py: conteos por barrio/severidad, filtrado por fecha.
#   9. main.py: crear app, incluir routers, CORS, health, crear tablas en startup.
#   10. Probar localmente (uvicorn) antes de contenerizar.
#
# 3) Pasos necesarios para la implementación de la base de datos
# - Definir modelos SQLAlchemy con índices para email.
# - Crear engine SQLite apuntando a /app/data/app.db (volumen).
# - Activar PRAGMA journal_mode=WAL y foreign_keys.
# - Crear tablas en startup (Base.metadata.create_all).
# - Opcional: sembrar usuario admin si no existe (omitido para simplicidad; puede añadirse en init/startup).
#
# 4) Pasos necesarios para la implementación del frontend (Streamlit)
# - Crear formulario de login, almacenar token en session_state.
# - Pantalla “Mi perfil” consultando /users/me.
# - CRUD de incidentes: formularios para crear/listar/borrar.
# - Analítica: filtros de fechas, consulta a /analytics/summary, gráficos (bar chart) y mapa (st.map/pydeck).
# - Configurar BACKEND_URL por variable de entorno (Compose).
#
# 5) Pasos necesarios para la contenerización
# - Dockerfile para backend y frontend con imágenes python:3.11-slim.
# - Volumen para persistir SQLite en backend (./data:/app/data).
# - Variables de entorno en .env (SECRET_KEY, DATABASE_URL, etc.).
# - docker-compose.yml con dos servicios, puertos 8000/8501, healthcheck y depends_on.
# - Arranque: docker compose up -d.
#
# 6) Puntos a favor y en contra de la arquitectura seleccionada
# - A favor:
#   - Simplicidad y productividad: FastAPI + Streamlit.
#   - Stateless en backend (JWT) facilita escalado horizontal del API.
#   - SQLite reduce complejidad de despliegue.
#   - Separación de responsabilidades clara (capas y contenedores).
# - En contra:
#   - SQLite no es ideal para alta concurrencia ni múltiples writers simultáneos.
#   - JWT sin lista de revocación complica invalidación temprana de tokens.
#   - Streamlit no es un framework SPA tradicional; limitado para escenarios complejos de UI.
#   - Sin migraciones (Alembic) en esta versión simplificada.
#
# 7) Puntos de mejora de la arquitectura seleccionada
# - Incorporar Alembic para migraciones.
# - Cambiar a Postgres para entornos multiusuario concurridos.
# - Añadir rate limiting, logging estructurado y trazas distribuidas.
# - Añadir refresh tokens y revocación, 2FA/OAuth2 social.
# - Tests unitarios y de integración (pytest + httpx).
# - Cache para endpoints analíticos (Redis).
# - CI/CD con build multi-stage y escaneo de vulnerabilidades.
#
# 8) Ejemplo de cada uno de los archivos generados en la arquitectura propuesta
# - backend/requirements.txt
#   fastapi==0.115.0
#   uvicorn==0.30.6
#   SQLAlchemy==2.0.35
#   pydantic==2.9.2
#   passlib[bcrypt]==1.7.4
#   PyJWT==2.9.0
#   python-multipart==0.0.9
#
# - backend/app/core/config.py
#   import os
#   from pydantic import BaseModel
#
#   class Settings(BaseModel):
#       PROJECT_NAME: str = "Urban ID & Incidents API"
#       SECRET_KEY: str = os.getenv("SECRET_KEY", "change_me")
#       ALGORITHM: str = "HS256"
#       ACCESS_TOKEN_EXPIRE_MINUTES: int = int(os.getenv("ACCESS_TOKEN_EXPIRE_MINUTES", "60"))
#       DATABASE_URL: str = os.getenv("DATABASE_URL", "sqlite:///./data/app.db")
#       BACKEND_CORS_ORIGINS: str = os.getenv("BACKEND_CORS_ORIGINS", "*")
#
#   settings = Settings()
#
# - backend/app/db/session.py
#   from sqlalchemy import create_engine, event
#   from sqlalchemy.orm import sessionmaker, declarative_base
#   from app.core.config import settings
#
#   connect_args = {}
#   if settings.DATABASE_URL.startswith("sqlite"):
#       connect_args = {"check_same_thread": False}
#
#   engine = create_engine(settings.DATABASE_URL, connect_args=connect_args, future=True)
#
#   @event.listens_for(engine, "connect")
#   def set_sqlite_pragma(dbapi_connection, connection_record):
#       cursor = dbapi_connection.cursor()
#       cursor.execute("PRAGMA journal_mode=WAL;")
#       cursor.execute("PRAGMA foreign_keys=ON;")
#       cursor.close()
#
#   SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine, future=True)
#   Base = declarative_base()
#
# - backend/app/db/models.py
#   from sqlalchemy import Column, Integer, String, Boolean, DateTime, Float, ForeignKey, Index
#   from sqlalchemy.orm import relationship
#   from datetime import datetime
#   from app.db.session import Base
#
#   class User(Base):
#       __tablename__ = "users"
#       id = Column(Integer, primary_key=True, index=True)
#       email = Column(String, unique=True, index=True, nullable=False)
#       hashed_password = Column(String, nullable=False)
#       full_name = Column(String, nullable=True)
#       is_active = Column(Boolean, default=True)
#       is_superuser = Column(Boolean, default=False)
#       created_at = Column(DateTime, default=datetime.utcnow)
#       incidents = relationship("Incident", back_populates="owner")
#
#   Index("ix_users_email_unique", User.email, unique=True)
#
#   class Incident(Base):
#       __tablename__ = "incidents"
#       id = Column(Integer, primary_key=True, index=True)
#       occurred_at = Column(DateTime, nullable=False)
#       type = Column(String, nullable=False)
#       severity = Column(Integer, nullable=False)
#       lat = Column(Float, nullable=False)
#       lon = Column(Float, nullable=False)
#       barrio = Column(String, nullable=True)
#       description = Column(String, nullable=True)
#       user_id = Column(Integer, ForeignKey("users.id"))
#       owner = relationship("User", back_populates="incidents")
#
# - backend/app/schemas/user.py
#   from pydantic import BaseModel, EmailStr
#
#   class UserBase(BaseModel):
#       email: EmailStr
#       full_name: str | None = None
#       is_active: bool | None = True
#       is_superuser: bool | None = False
#
#   class UserCreate(BaseModel):
#       email: EmailStr
#       password: str
#       full_name: str | None = None
#
#   class UserUpdate(BaseModel):
#       full_name: str | None = None
#       is_active: bool | None = None
#       is_superuser: bool | None = None
#
#   class UserRead(UserBase):
#       id: int
#       class Config:
#           from_attributes = True
#
#   class Token(BaseModel):
#       access_token: str
#       token_type: str = "bearer"
#
#   class LoginRequest(BaseModel):
#       email: EmailStr
#       password: str
#
# - backend/app/schemas/incident.py
#   from pydantic import BaseModel
#   from datetime import datetime
#
#   class IncidentBase(BaseModel):
#       occurred_at: datetime
#       type: str
#       severity: int
#       lat: float
#       lon: float
#       barrio: str | None = None
#       description: str | None = None
#
#   class IncidentCreate(IncidentBase):
#       pass
#
#   class IncidentUpdate(BaseModel):
#       type: str | None = None
#       severity: int | None = None
#       lat: float | None = None
#       lon: float | None = None
#       barrio: str | None = None
#       description: str | None = None
#       occurred_at: datetime | None = None
#
#   class IncidentRead(IncidentBase):
#       id: int
#       user_id: int | None = None
#       class Config:
#           from_attributes = True
#
#   class AnalyticsSummary(BaseModel):
#       total: int
#       by_barrio: dict[str, int]
#       by_severity: dict[int, int]
#
# - backend/app/core/security.py
#   from datetime import datetime, timedelta, timezone
#   from passlib.context import CryptContext
#   import jwt
#
#   pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")
#
#   def verify_password(plain_password: str, hashed_password: str) -> bool:
#       return pwd_context.verify(plain_password, hashed_password)
#
#   def get_password_hash(password: str) -> str:
#       return pwd_context.hash(password)
#
#   def create_access_token(subject: dict, secret_key: str, algorithm: str, expires_minutes: int) -> str:
#       to_encode = subject.copy()
#       expire = datetime.now(timezone.utc) + timedelta(minutes=expires_minutes)
#       to_encode.update({"exp": expire})
#       return jwt.encode(to_encode, secret_key, algorithm=algorithm)
#
# - backend/app/api/deps.py
#   from fastapi import Depends, HTTPException, status
#   from fastapi.security import HTTPAuthorizationCredentials, HTTPBearer
#   from sqlalchemy.orm import Session
#   import jwt
#   from app.db.session import SessionLocal
#   from app.core.config import settings
#   from app.db import models
#
#   security = HTTPBearer()
#
#   def get_db():
#       db = SessionLocal()
#       try:
#           yield db
#       finally:
#           db.close()
#
#   def get_current_user(
#       creds: HTTPAuthorizationCredentials = Depends(security),
#       db: Session = Depends(get_db),
#   ) -> models.User:
#       token = creds.credentials
#       try:
#           payload = jwt.decode(token, settings.SECRET_KEY, algorithms=[settings.ALGORITHM])
#       except jwt.PyJWTError:
#           raise HTTPException(status_code=status.HTTP_401_UNAUTHORIZED, detail="Token inválido")
#       user_id = payload.get("sub")
#       if not user_id:
#           raise HTTPException(status_code=401, detail="Token inválido (sin sub)")
#       user = db.get(models.User, int(user_id))
#       if not user or not user.is_active:
#           raise HTTPException(status_code=401, detail="Usuario no encontrado o inactivo")
#       return user
#
#   def get_current_active_user(user: models.User = Depends(get_current_user)) -> models.User:
#       if not user.is_active:
#           raise HTTPException(status_code=400, detail="Usuario inactivo")
#       return user
#
#   def get_current_superuser(user: models.User = Depends(get_current_user)) -> models.User:
#       if not user.is_superuser:
#           raise HTTPException(status_code=403, detail="No autorizado (requiere superusuario)")
#       return user
#
# - backend/app/api/v1/endpoints/auth.py
#   from fastapi import APIRouter, Depends, HTTPException, status
#   from sqlalchemy.orm import Session
#   from app.schemas.user import UserCreate, LoginRequest, Token, UserRead
#   from app.db import models
#   from app.db.session import SessionLocal
#   from app.core.security import get_password_hash, verify_password, create_access_token
#   from app.core.config import settings
#
#   router = APIRouter(prefix="/auth", tags=["auth"])
#
#   def get_db():
#       db = SessionLocal()
#       try:
#           yield db
#       finally:
#           db.close()
#
#   @router.post("/register", response_model=UserRead, status_code=201)
#   def register(user_in: UserCreate, db: Session = Depends(get_db)):
#       exists = db.query(models.User).filter(models.User.email == user_in.email).first()
#       if exists:
#           raise HTTPException(status_code=400, detail="Email ya registrado")
#       user = models.User(
#           email=user_in.email,
#           full_name=user_in.full_name,
#           hashed_password=get_password_hash(user_in.password),
#           is_active=True,
#           is_superuser=False,
#       )
#       db.add(user)
#       db.commit()
#       db.refresh(user)
#       return user
#
#   @router.post("/login", response_model=Token)
#   def login(login: LoginRequest, db: Session = Depends(get_db)):
#       user = db.query(models.User).filter(models.User.email == login.email).first()
#       if not user or not verify_password(login.password, user.hashed_password):
#           raise HTTPException(status_code=401, detail="Credenciales inválidas")
#       token = create_access_token(
#           {"sub": str(user.id), "email": user.email},
#           secret_key=settings.SECRET_KEY,
#           algorithm=settings.ALGORITHM,
#           expires_minutes=settings.ACCESS_TOKEN_EXPIRE_MINUTES,
#       )
#       return {"access_token": token, "token_type": "bearer"}
#
# - backend/app/api/v1/endpoints/users.py
#   from fastapi import APIRouter, Depends, HTTPException, status
#   from sqlalchemy.orm import Session
#   from app.api.deps import get_db, get_current_active_user, get_current_superuser
#   from app.db import models
#   from app.schemas.user import UserRead, UserUpdate, UserCreate
#   from app.core.security import get_password_hash
#
#   router = APIRouter(prefix="/users", tags=["users"])
#
#   @router.get("/me", response_model=UserRead)
#   def read_me(current=Depends(get_current_active_user)):
#       return current
#
#   @router.get("/", response_model=list[UserRead], dependencies=[Depends(get_current_superuser)])
#   def list_users(db: Session = Depends(get_db)):
#       return db.query(models.User).all()
#
#   @router.post("/", response_model=UserRead, status_code=201, dependencies=[Depends(get_current_superuser)])
#   def create_user(user_in: UserCreate, db: Session = Depends(get_db)):
#       if db.query(models.User).filter(models.User.email == user_in.email).first():
#           raise HTTPException(status_code=400, detail="Email ya registrado")
#       user = models.User(
#           email=user_in.email,
#           full_name=user_in.full_name,
#           hashed_password=get_password_hash(user_in.password),
#           is_active=True,
#       )
#       db.add(user); db.commit(); db.refresh(user)
#       return user
#
#   @router.patch("/{user_id}", response_model=UserRead, dependencies=[Depends(get_current_superuser)])
#   def update_user(user_id: int, user_in: UserUpdate, db: Session = Depends(get_db)):
#       user = db.get(models.User, user_id)
#       if not user:
#           raise HTTPException(status_code=404, detail="Usuario no encontrado")
#       for k, v in user_in.model_dump(exclude_unset=True).items():
#           setattr(user, k, v)
#       db.commit(); db.refresh(user)
#       return user
#
#   @router.delete("/{user_id}", status_code=204, dependencies=[Depends(get_current_superuser)])
#   def delete_user(user_id: int, db: Session = Depends(get_db)):
#       user = db.get(models.User, user_id)
#       if not user:
#           raise HTTPException(status_code=404, detail="Usuario no encontrado")
#       db.delete(user); db.commit()
#       return
#
# - backend/app/api/v1/endpoints/incidents.py
#   from fastapi import APIRouter, Depends, HTTPException, status, Query
#   from sqlalchemy.orm import Session
#   from app.api.deps import get_db, get_current_active_user
#   from app.db import models
#   from app.schemas.incident import IncidentCreate, IncidentRead, IncidentUpdate
#   from datetime import datetime
#
#   router = APIRouter(prefix="/incidents", tags=["incidents"])
#
#   @router.post("/", response_model=IncidentRead, status_code=201)
#   def create_incident(inc: IncidentCreate, db: Session = Depends(get_db), user=Depends(get_current_active_user)):
#       obj = models.Incident(**inc.model_dump(), user_id=user.id)
#       db.add(obj); db.commit(); db.refresh(obj)
#       return obj
#
#   @router.get("/", response_model=list[IncidentRead])
#   def list_incidents(
#       db: Session = Depends(get_db),
#       user=Depends(get_current_active_user),
#       limit: int = Query(100, le=1000),
#       skip: int = 0,
#   ):
#       q = db.query(models.Incident).order_by(models.Incident.occurred_at.desc()).offset(skip).limit(limit)
#       return q.all()
#
#   @router.get("/{incident_id}", response_model=IncidentRead)
#   def get_incident(incident_id: int, db: Session = Depends(get_db), user=Depends(get_current_active_user)):
#       obj = db.get(models.Incident, incident_id)
#       if not obj:
#           raise HTTPException(status_code=404, detail="No encontrado")
#       return obj
#
#   @router.patch("/{incident_id}", response_model=IncidentRead)
#   def update_incident(incident_id: int, inc: IncidentUpdate, db: Session = Depends(get_db), user=Depends(get_current_active_user)):
#       obj = db.get(models.Incident, incident_id)
#       if not obj:
#           raise HTTPException(status_code=404, detail="No encontrado")
#       for k, v in inc.model_dump(exclude_unset=True).items():
#           setattr(obj, k, v)
#       db.commit(); db.refresh(obj)
#       return obj
#
#   @router.delete("/{incident_id}", status_code=204)
#   def delete_incident(incident_id: int, db: Session = Depends(get_db), user=Depends(get_current_active_user)):
#       obj = db.get(models.Incident, incident_id)
#       if not obj:
#           raise HTTPException(status_code=404, detail="No encontrado")
#       db.delete(obj); db.commit()
#       return
#
# - backend/app/api/v1/endpoints/analytics.py
#   from fastapi import APIRouter, Depends, Query
#   from sqlalchemy.orm import Session
#   from sqlalchemy import func
#   from datetime import datetime
#   from app.api.deps import get_db, get_current_active_user
#   from app.db import models
#   from app.schemas.incident import AnalyticsSummary
#
#   router = APIRouter(prefix="/analytics", tags=["analytics"])
#
#   @router.get("/summary", response_model=AnalyticsSummary)
#   def analytics_summary(
#       db: Session = Depends(get_db),
#       user=Depends(get_current_active_user),
#       start: datetime | None = Query(None),
#       end: datetime | None = Query(None),
#   ):
#       q = db.query(models.Incident)
#       if start:
#           q = q.filter(models.Incident.occurred_at >= start)
#       if end:
#           q = q.filter(models.Incident.occurred_at <= end)
#
#       total = q.count()
#
#       by_barrio_rows = (
#           db.query(models.Incident.barrio, func.count(models.Incident.id))
#           .filter(models.Incident.id.in_([i.id for i in q.all()]))
#           .group_by(models.Incident.barrio)
#           .all()
#       )
#       by_barrio = {k or "N/A": v for k, v in by_barrio_rows}
#
#       by_sev_rows = (
#           db.query(models.Incident.severity, func.count(models.Incident.id))
#           .filter(models.Incident.id.in_([i.id for i in q.all()]))
#           .group_by(models.Incident.severity)
#           .all()
#       )
#       by_severity = {int(k): v for k, v in by_sev_rows}
#       return AnalyticsSummary(total=total, by_barrio=by_barrio, by_severity=by_severity)
#
# - backend/app/api/v1/api.py
#   from fastapi import APIRouter
#   from app.api.v1.endpoints import auth, users, incidents, analytics
#
#   api_router = APIRouter()
#   api_router.include_router(auth.router)
#   api_router.include_router(users.router)
#   api_router.include_router(incidents.router)
#   api_router.include_router(analytics.router)
#
# - backend/app/main.py
#   from fastapi import FastAPI
#   from fastapi.middleware.cors import CORSMiddleware
#   from app.core.config import settings
#   from app.db.session import Base, engine
#   from app.api.v1.api import api_router
#
#   app = FastAPI(title=settings.PROJECT_NAME)
#
#   app.add_middleware(
#       CORSMiddleware,
#       allow_origins=[settings.BACKEND_CORS_ORIGINS] if settings.BACKEND_CORS_ORIGINS != "*" else ["*"],
#       allow_credentials=True,
#       allow_methods=["*"],
#       allow_headers=["*"],
#   )
#
#   @app.on_event("startup")
#   def on_startup():
#       Base.metadata.create_all(bind=engine)
#
#   @app.get("/health")
#   def health():
#       return {"status": "ok"}
#
#   app.include_router(api_router, prefix="/api/v1")
#
# - backend/Dockerfile
#   FROM python:3.11-slim
#   WORKDIR /app
#   ENV PYTHONDONTWRITEBYTECODE=1
#   ENV PYTHONUNBUFFERED=1
#   COPY backend/requirements.txt .
#   RUN pip install --no-cache-dir -r requirements.txt
#   COPY backend/app ./app
#   EXPOSE 8000
#   CMD ["uvicorn", "app.main:app", "--host", "0.0.0.0", "--port", "8000"]
#
# - frontend/requirements.txt
#   streamlit==1.37.1
#   requests==2.32.3
#   pandas==2.2.2
#   pydeck==0.9.1
#
# - frontend/app.py
#   import os
#   import requests
#   import streamlit as st
#   import pandas as pd
#   from datetime import datetime, timedelta
#
#   BACKEND_URL = os.getenv("BACKEND_URL", "http://localhost:8000")
#
#   st.set_page_config(page_title="Urban Incidents Dashboard", layout="wide")
#
#   if "token" not in st.session_state:
#       st.session_state.token = None
#
#   def auth_headers():
#       if st.session_state.token:
#           return {"Authorization": f"Bearer {st.session_state.token}"}
#       return {}
#
#   with st.sidebar:
#       st.title("Autenticación")
#       email = st.text_input("Email")
#       password = st.text_input("Password", type="password")
#       if st.button("Login"):
#           r = requests.post(f"{BACKEND_URL}/api/v1/auth/login", json={"email": email, "password": password})
#           if r.status_code == 200:
#               st.session_state.token = r.json()["access_token"]
#               st.success("Login exitoso")
#           else:
#               st.error(r.text)
#       if st.button("Logout"):
#           st.session_state.token = None
#
#   st.title("Gestión de Incidentes Urbanos")
#
#   if st.session_state.token:
#       col1, col2 = st.columns(2)
#       with col1:
#           st.subheader("Mi perfil")
#           me = requests.get(f"{BACKEND_URL}/api/v1/users/me", headers=auth_headers())
#           if me.ok:
#               st.json(me.json())
#           else:
#               st.warning("No se pudo obtener el perfil")
#
#       with col2:
#           st.subheader("Crear incidente")
#           with st.form("create_incident"):
#               occurred_at = st.datetime_input("Fecha/Hora", value=datetime.utcnow())
#               type_ = st.text_input("Tipo", value="accidente")
#               severity = st.number_input("Severidad (1-5)", min_value=1, max_value=5, value=3)
#               lat = st.number_input("Latitud", value=40.4168, format="%.6f")
#               lon = st.number_input("Longitud", value=-3.7038, format="%.6f")
#               barrio = st.text_input("Barrio", value="Centro")
#               description = st.text_area("Descripción", value="")
#               submitted = st.form_submit_button("Crear")
#               if submitted:
#                   payload = {
#                       "occurred_at": occurred_at.isoformat(),
#                       "type": type_,
#                       "severity": int(severity),
#                       "lat": float(lat),
#                       "lon": float(lon),
#                       "barrio": barrio or None,
#                       "description": description or None
#                   }
#                   r = requests.post(f"{BACKEND_URL}/api/v1/incidents/", json=payload, headers=auth_headers())
#                   if r.ok:
#                       st.success("Incidente creado")
#                   else:
#                       st.error(r.text)
#
#       st.subheader("Listado y Mapa")
#       lst = requests.get(f"{BACKEND_URL}/api/v1/incidents/", headers=auth_headers(), params={"limit": 500})
#       if lst.ok:
#           data = pd.DataFrame(lst.json())
#           if not data.empty:
#               st.dataframe(data)
#               map_df = data.rename(columns={"lat": "latitude", "lon": "longitude"})
#               st.map(map_df[["latitude", "longitude"]])
#           else:
#               st.info("Sin incidentes registrados.")
#       else:
#           st.error(lst.text)
#
#       st.subheader("Analítica")
#       c1, c2 = st.columns(2)
#       with c1:
#           start = st.date_input("Inicio", value=datetime.utcnow().date() - timedelta(days=30))
#       with c2:
#           end = st.date_input("Fin", value=datetime.utcnow().date())
#       params = {"start": f"{start}T00:00:00", "end": f"{end}T23:59:59"}
#       ana = requests.get(f"{BACKEND_URL}/api/v1/analytics/summary", headers=auth_headers(), params=params)
#       if ana.ok:
#           summary = ana.json()
#           st.metric("Total incidentes", summary["total"])
#           if summary["by_barrio"]:
#               bb = pd.DataFrame(list(summary["by_barrio"].items()), columns=["barrio", "count"]).sort_values("count", ascending=False)
#               st.bar_chart(bb.set_index("barrio"))
#           if summary["by_severity"]:
#               bs = pd.DataFrame(list(summary["by_severity"].items()), columns=["severity", "count"]).sort_values("severity")
#               st.bar_chart(bs.set_index("severity"))
#       else:
#           st.error(ana.text)
#   else:
#       st.info("Por favor, inicia sesión para continuar.")
#
# - frontend/Dockerfile
#   FROM python:3.11-slim
#   WORKDIR /app
#   COPY frontend/requirements.txt .
#   RUN pip install --no-cache-dir -r requirements.txt
#   COPY frontend/app.py .
#   EXPOSE 8501
#   CMD ["streamlit", "run", "app.py", "--server.address=0.0.0.0", "--server.port=8501"]
#
# - docker-compose.yml
#   version: "3.9"
#   services:
#     backend:
#       build:
#         context: .
#         dockerfile: backend/Dockerfile
#       env_file:
#         - .env
#       volumes:
#         - ./data:/app/data
#       ports:
#         - "8000:8000"
#       healthcheck:
#         test: ["CMD", "curl", "-f", "http://localhost:8000/health"]
#         interval: 10s
#         timeout: 3s
#         retries: 5
#       restart: unless-stopped
#
#     frontend:
#       build:
#         context: .
#         dockerfile: frontend/Dockerfile
#       environment:
#         - BACKEND_URL=http://backend:8000
#       ports:
#         - "8501:8501"
#       depends_on:
#         backend:
#           condition: service_healthy
#       restart: unless-stopped
#
# - .env.example
#   SECRET_KEY=change_me_please
#   ACCESS_TOKEN_EXPIRE_MINUTES=60
#   DATABASE_URL=sqlite:///./data/app.db
#   BACKEND_CORS_ORIGINS=*
#
# - backend/app/__init__.py
#   # vacío intencionalmente
#
# - backend/app/api/__init__.py
#   # vacío intencionalmente
#
# - backend/app/api/v1/__init__.py
#   # vacío intencionalmente
#
# - backend/app/db/__init__.py
#   # vacío intencionalmente
#
# - backend/app/schemas/__init__.py
#   # vacío intencionalmente
#
# Guía rápida de ejecución
# - Desarrollo local (sin Docker):
#   - Backend:
#     - cd backend
#     - python -m venv .venv && source .venv/bin/activate
#     - pip install -r requirements.txt
#     - export SECRET_KEY=change_me DATABASE_URL=sqlite:///./data/app.db
#     - mkdir -p ../data
#     - uvicorn app.main:app --reload
#   - Frontend:
#     - cd frontend
#     - python -m venv .venv && source .venv/bin/activate
#     - pip install -r requirements.txt
#     - export BACKEND_URL=http://localhost:8000
#     - streamlit run app.py
# - Con Docker Compose:
#   - cp .env.example .env
#   - mkdir -p data
#   - docker compose up -d
#   - Backend en http://localhost:8000/docs
#   - Frontend en http://localhost:8501
#
# Notas finales
# - La API está namespaced en /api/v1.
# - Seguridad: HS256 con SECRET_KEY; mantenerlo fuera del repositorio y rotarlo en producción.
# - SQLite con WAL para mejorar lectura concurrente. Para producción multiusuario intenso, migrar a Postgres + Alembic.
# - La analítica es básica y se puede extender con endpoints para heatmaps, exportaciones CSV y agregaciones avanzadas.

# %%
# Inicilaizamos con el modelo gpt-4o-mini para reducir costos y comparar salidas
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

# %%
# Ejecutamos el prompt e imprimimos el resultado ahora con el modelo gpt-4o-mini
few_shot_cot_create_response_4o = llm.invoke(few_shot_cot_create)
print(few_shot_cot_create_response_4o.content)
# Out:
# ### 1. Estructura básica de la app
#
# La estructura básica de la aplicación se puede organizar de la siguiente manera:
#
# ```
# digital_identity_management/
# │
# ├── backend/
# │   ├── app/
# │   │   ├── __init__.py
# │   │   ├── main.py
# │   │   ├── models.py
# │   │   ├── routes.py
# │   │   ├── database.py
# │   │   └── auth.py
# │   ├── requirements.txt
# │   └── Dockerfile
# │
# ├── frontend/
# │   ├── app.py
# │   └── requirements.txt
# │
# ├── docker-compose.yml
# └── README.md
# ```
#
# ### 2. Pasos necesarios para la implementación del backend
#
# 1. **Crear el entorno de trabajo**:
#    - Crear la carpeta `backend/app` y los archivos mencionados en la estructura.
#
# 2. **Instalar dependencias**:
#    - Crear un archivo `requirements.txt` en `backend` con las siguientes dependencias:
#      ```
#      fastapi
#      uvicorn
#      sqlalchemy
#      sqlite
#      passlib[bcrypt]
#      ```
#
# 3. **Configurar la base de datos**:
#    - En `database.py`, configurar la conexión a SQLite usando SQLAlchemy.
#
# 4. **Definir modelos**:
#    - En `models.py`, definir los modelos de usuario y accidentes.
#
# 5. **Implementar rutas**:
#    - En `routes.py`, implementar las rutas para el CRUD de usuarios y la gestión de accidentes.
#
# 6. **Implementar autenticación**:
#    - En `auth.py`, implementar la lógica de autenticación y autorización.
#
# 7. **Crear el archivo principal**:
#    - En `main.py`, inicializar la aplicación FastAPI y incluir las rutas.
#
# 8. **Crear el Dockerfile**:
#    - Crear un `Dockerfile` para el backend que instale las dependencias y ejecute el servidor.
#
# ### 3. Pasos necesarios para la implementación de la base de datos
#
# 1. **Definir la estructura de la base de datos**:
#    - En `models.py`, definir las tablas necesarias para usuarios y accidentes.
#
# 2. **Crear la base de datos**:
#    - Usar SQLAlchemy para crear la base de datos y las tablas al iniciar la aplicación.
#
# 3. **Implementar funciones CRUD**:
#    - En `routes.py`, implementar las funciones para crear, leer, actualizar y eliminar usuarios y accidentes.
#
# ### 4. Pasos necesarios para la implementación del frontend
#
# 1. **Crear el entorno de trabajo**:
#    - Crear la carpeta `frontend` y el archivo `app.py`.
#
# 2. **Instalar dependencias**:
#    - Crear un archivo `requirements.txt` en `frontend` con la siguiente dependencia:
#      ```
#      streamlit
#      requests
#      ```
#
# 3. **Desarrollar la interfaz de usuario**:
#    - En `app.py`, usar Streamlit para crear formularios y visualizaciones para la gestión de usuarios y accidentes.
#
# 4. **Conectar con el backend**:
#    - Usar la librería `requests` para hacer llamadas a la API REST del backend.
#
# ### 5. Pasos necesarios para la contenerización
#
# 1. **Crear el archivo `docker-compose.yml`**:
#    - Definir los servicios para el backend y el frontend, especificando las imágenes y los puertos.
#
# 2. **Construir las imágenes**:
#    - Usar `docker-compose build` para construir las imágenes de los servicios.
#
# 3. **Ejecutar los contenedores**:
#    - Usar `docker-compose up` para iniciar los contenedores.
#
# ### 6. Puntos a favor y en contra de la arquitectura seleccionada
#
# **Puntos a favor**:
# - **Simplicidad**: La arquitectura es fácil de entender y mantener.
# - **Escalabilidad**: Se puede escalar fácilmente al agregar más servicios o funcionalidades.
# - **Desarrollo rápido**: Usar FastAPI y Streamlit permite un desarrollo ágil.
#
# **Puntos en contra**:
# - **Limitaciones de SQLite**: No es ideal para aplicaciones con alta concurrencia.
# - **Seguridad**: La autenticación y autorización deben ser implementadas cuidadosamente para evitar vulnerabilidades.
#
# ### 7. Puntos de mejora de la arquitectura seleccionada
#
# - **Migrar a una base de datos más robusta**: Considerar el uso de PostgreSQL o MySQL para producción.
# - **Implementar pruebas automatizadas**: Agregar pruebas unitarias y de integración para asegurar la calidad del código.
# - **Mejorar la seguridad**: Implementar medidas adicionales de seguridad, como la validación de entradas y la protección contra ataques CSRF.
#
# ### 8. Ejemplo de cada uno de los archivos generados en la arquitectura propuesta
#
# **backend/app/main.py**:
# ```python
# from fastapi import FastAPI
# from .routes import router
#
# app = FastAPI()
#
# app.include_router(router)
#
# @app.get("/")
# def read_root():
#     return {"message": "Welcome to the Digital Identity Management API"}
# ```
#
# **backend/app/models.py**:
# ```python
# from sqlalchemy import Column, Integer, String
# from .database import Base
#
# class User(Base):
#     __tablename__ = "users"
#
#     id = Column(Integer, primary_key=True, index=True)
#     username = Column(String, unique=True, index=True)
#     password = Column(String)
# ```
#
# **backend/app/routes.py**:
# ```python
# from fastapi import APIRouter, Depends
# from .models import User
# from .database import SessionLocal
#
# router = APIRouter()
#
# @router.post("/users/")
# def create_user(user: User):
#     db = SessionLocal()
#     db.add(user)
#     db.commit()
#     db.refresh(user)
#     return user
# ```
#
# **frontend/app.py**:
# ```python
# import streamlit as st
# import requests
#
# st.title("Digital Identity Management")
#
# username = st.text_input("Username")
# password = st.text_input("Password", type="password")
#
# if st.button("Create User"):
#     response = requests.post("http://backend:8000/users/", json={"username": username, "password": password})
#     st.write(response.json())
# ```
#
# **docker-compose.yml**:
# ```yaml
# version: '3.8'
#
# services:
#   backend:
#     build: ./backend
#     ports:
#       - "8000:8000"
#
#   frontend:
#     build: ./frontend
#     ports:
#       - "8501:8501"
# ```
#
# Con esta arquitectura y los pasos descritos, tendrás un sistema CRUD funcional para la gestión de la identidad digital de usuarios, optimizado para el rendimiento y la mantenibilidad.

# %% [markdown]
# Los resultados obtenidos con el modelo gpt-5 son muchos mas completos, y se opta por usar este modelo para la generación del pipeline para obtener la arquitectura de la aplicación

# %% [markdown]
# ## Pipeline para el diseño de la arquitectura usando las recomendaciones de la IA, para el frontend y la base de datos

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field
from typing import Optional

# %%
# Creamos la estructira de salida para el parser

class CodeOutput(BaseModel):
    estructura: str = Field(..., description="Explicacion de la estructura de la app")
    backend: str = Field(..., description="Explicación del backend con archivos")
    database: str = Field(..., description="Explicación de la base de datos")
    frontend: str = Field(..., description="Explicación del frontend")
    container: str = Field(..., description="Explicación de la contenerizacion")
    improvements: Optional[str] = Field(None, description="Sugerencias para mejorar la arquitectura de la app.")

parser = PydanticOutputParser(pydantic_object=CodeOutput)

# %%
# Establecemos el modelo
model = ChatOpenAI(model="gpt-5", temperature=0)

# %%
# Establecemos el prompt
prompt = ChatPromptTemplate.from_messages([
    ("system", """
     Actúa como un arquitecto senior de software de Python especializado con mas de 10 años de experiencia en sistemas CRUD, 
     y amplia experiencia en implementaciones en Dockers Compose.

    CONTEXTO: Estoy trabajando en la implementación de un sistema CRUD para la gestion de la identidad digital de usuarios
    optimizando el código, la arquitectura del software y los procesos para mejorar el performance, la seguridad y
    la mantenibilidad de la app.

    PRINCIPIOS:
    - La arquitectura debe de seguir las mejores practicas
    - Arquitectura simple pero funcional
    - Utilizar la técnica de Chain of Thoughts para el diseño de la arquitectura.
    """),
    ("human", """
    OBJETIVO: {objetivo}
     REQUISITOS: {requisitos}
     ESPECIFICACIONES: {especificaciones}
     {format_instructions}
     """)
])

# %%
# Creamos el pipeline
chain = prompt | model | parser

# %%
# Establecemos las inputs para el prompt
inputs = {
    "objetivo": "Crear la arquitectura de la app para la gestion de un sistema CRUD completo.",
    "requisitos": """Crear la arquitectura de la app para la gestion de un sistema CRUD que:
        - Incluya los siguientes componentes: backend, frontend, base de datos y contenerizacion basica.
        - Implemente funcionalidades core de autneticación, gestion de usuarios, y una caracteristica de analisis urbano
        como accidentes o inicidentes de trafico.
        - Defina una arquitectura simplificada pero funcional.""",
    "especificaciones": """
    - Debe de usar API Rest para el backend.
    - Debe de tener una arquitectura simplificada pero funcional.
    - Debe de incluir ejemplos de la arquitectura.
    - Debe de describir el proceso de diseño en pasos enumerados.
    - Debe de incluir los puntos a favor y en contra de la arquitectura seleccionada.
    - Debe de incluir los puntos de mejora de la arquitectura seleccionada.""",
    "format_instructions": parser.get_format_instructions()
}

# %%
# Ejecutamos el pipeline
result = chain.invoke(inputs)

# %%
# Imprimimos la estructura de la app generada
print(result.estructura)
# Out:
# Arquitectura general (3 capas + contenedores):
# - Frontend (SPA React): UI, manejo de sesión, llamadas a API, visualización y analítica básica.
# - Backend (API REST con FastAPI): autenticación JWT, CRUD de usuarios, CRUD de incidentes, endpoints de analítica.
# - Base de datos (PostgreSQL): persistencia relacional, índices, migraciones.
# - Contenerización (Docker Compose): orquestación local de frontend, backend y base de datos.
#
# Diagrama lógico (texto):
# [React SPA] --HTTP/HTTPS--> [FastAPI] --SQL--> [PostgreSQL]
#                                  ^
#                            OpenAPI/Swagger
#
# Proceso de diseño (pasos enumerados):
# 1) Definir dominios: identidad (usuarios/roles/sesiones) y urbano (incidentes/analítica).
# 2) Elegir patrones: API REST, capas limpias (routers -> services -> repos -> db), DTOs con Pydantic.
# 3) Seguridad: JWT acceso+refresh, hashing de contraseñas, CORS, validación.
# 4) Modelo de datos: users, roles, user_roles, refresh_tokens, incidents.
# 5) Endpoints: auth (login, refresh, logout), users (CRUD), incidents (CRUD), analytics (resúmenes).
# 6) Escalabilidad local: Docker Compose con redes, volúmenes y healthchecks.
# 7) Observabilidad básica: logs estructurados y métricas simples.
# 8) Performance inicial: índices en claves de búsqueda, paginación, filtros.
# 9) Mantenibilidad: estructura de carpetas por capas, migraciones con Alembic, pruebas unitarias.
# 10) Entrega: .env, docker-compose.yml, scripts de make.
#
# Ejemplo de estructura de repositorio:
# - backend/
#   - app/
#     - main.py
#     - api/routers/{auth.py, users.py, incidents.py, analytics.py}
#     - core/{config.py, security.py}
#     - models/{user.py, incident.py}
#     - schemas/{user.py, incident.py, auth.py}
#     - services/{user_service.py, incident_service.py, analytics_service.py}
#     - repositories/{user_repo.py, incident_repo.py}
#     - db/{session.py}
#     - migrations/
#   - tests/
# - frontend/
#   - src/{pages, components, services, hooks, store}
# - deploy/
#   - docker-compose.yml
#   - nginx/
# - .env
#
# Pros:
# - Simple, separada por capas y fácil de entender.
# - FastAPI provee tipado, validación y docs automáticas.
# - Postgres confiable para transaccional y agregaciones básicas.
# - Compose acelera desarrollo local y onboarding.
#
# Contras:
# - Sin PostGIS, las consultas geo espaciales son limitadas.
# - JWT stateless requiere cuidado con revocación/rotación.
# - Un solo backend: sin separación de responsabilidades para analítica pesada.
# - Sin proxy TLS/edge en esta versión básica.

# %%
# Imprimimos la escritura del backend generado
print(result.backend)
# Out:
# Tecnología y librerías:
# - Python 3.12, FastAPI, Uvicorn, SQLAlchemy 2.x, Alembic, Pydantic v2, Passlib (argon2 o bcrypt), PyJWT.
#
# Capas y responsabilidades:
# - Routers (FastAPI APIRouter): definen endpoints y validaciones de entrada/salida.
# - Services: lógica de negocio (reglas, transacciones orquestadas).
# - Repositories: acceso a datos con SQLAlchemy ORM/SQL.
# - Schemas (Pydantic): DTOs para requests/responses.
# - Core: configuración, seguridad, middlewares.
#
# Autenticación y autorización:
# - Login con email+password. Hash con Argon2 (recomendado) o bcrypt.
# - JWT de acceso (vida corta, Authorization: Bearer) y refresh (httpOnly, Secure cookie).
# - RBAC simple: roles [admin, analyst, user]. Dependencias de ruta verifican scopes/roles.
#
# Endpoints principales (ejemplos):
# - POST /auth/login
# - POST /auth/refresh
# - POST /auth/logout
# - GET /users (paginado, filtros: email, role)
# - POST /users, GET /users/{id}, PUT /users/{id}, DELETE /users/{id}
# - GET /incidents (paginado, filtros: from, to, severity, city, bbox opcional)
# - POST /incidents, GET /incidents/{id}, PUT /incidents/{id}, DELETE /incidents/{id}
# - GET /analytics/incidents/summary?from=YYYY-MM-DD&to=YYYY-MM-DD
# - GET /analytics/incidents/by-severity?from=...&to=...
#
# Ejemplos de modelos (resumidos):
# - User: id, email, hashed_password, full_name, is_active, created_at.
# - Role: id, name.
# - UserRole: user_id, role_id.
# - RefreshToken: id, user_id, token_hash, exp, revoked.
# - Incident: id, title, description, occurred_at, severity(enum), lat, lon, city, status, created_by.
#
# Ejemplo de router (simplificado):
# from fastapi import APIRouter, Depends
# from app.schemas.incident import IncidentCreate, IncidentRead
# from app.services.incident_service import IncidentService
#
# router = APIRouter(prefix='/incidents', tags=['incidents'])
#
# @router.post('', response_model=IncidentRead)
# async def create_incident(payload: IncidentCreate, svc: IncidentService = Depends()):
#     return await svc.create(payload)
#
# Buenas prácticas aplicadas:
# - Paginación y ordenamiento por defecto; filtros seguros.
# - Validación estricta con Pydantic y tipos enum.
# - Manejo de errores uniforme (HTTPException mapeada a códigos estándar).
# - CORS restringido por entorno.
# - Logging estructurado (JSON) y correlación de request-id.
# - OpenAPI auto-generado con ejemplos y tags.
#
# Puntos a favor:
# - Capas claras facilitan pruebas y cambios.
# - FastAPI es performante y expresivo.
#
# Puntos en contra:
# - Sin caché/cola, algunas analíticas pueden ser lentas bajo carga.
# - Revocación de tokens requiere tabla/estrategia adicional.
#
# Puntos de mejora inmediatos:
# - Añadir rate limiting (SlowAPI) y auditoría.
# - Añadir queries pre-agregadas/materialized views para analítica.
# - Separar worker para tareas programadas (limpieza de tokens, agregaciones).

# %%
# Imprimimos la arquietectura del front generado
print(result.frontend)
# Out:
# Tecnología: React + Vite, TypeScript, React Router, React Query (tanstack), UI library (MUI), axios.
#
# Páginas clave:
# - /login: formulario de autenticación.
# - /users: listado CRUD con búsqueda y paginación.
# - /incidents: listado y detalle; creación/edición.
# - /dashboard: tarjetas de KPIs, gráficos de incidentes por día y severidad; mapa simple (Leaflet) opcional.
#
# Estado y servicios:
# - React Query para fetching/caching y reintentos.
# - Interceptor axios añade Authorization Bearer y maneja refresh token.
# - Guarded routes según rol (admin/analyst/user).
#
# Estructura (resumen):
# - src/
#   - pages/{Login.tsx, Users.tsx, Incidents.tsx, Dashboard.tsx}
#   - components/{UserForm.tsx, IncidentForm.tsx, Charts.tsx}
#   - services/{api.ts, users.ts, incidents.ts, auth.ts}
#   - hooks/{useAuth.ts}
#   - store/{authStore.ts}
#   - routes.tsx
#
# Ejemplo servicio API:
# // services/api.ts
# import axios from 'axios'
# const api = axios.create({ baseURL: import.meta.env.VITE_API_URL })
# api.interceptors.response.use(r => r, async err => { /* refresh token flow */ return Promise.reject(err) })
# export default api
#
# // services/incidents.ts
# import api from './api'
# export const listIncidents = (params) => api.get('/incidents', { params })
#
# Pros:
# - SPA ligera, rápido desarrollo.
# - React Query simplifica el manejo de datos y estados de red.
#
# Contras:
# - SEO no prioritario (SPA).
# - Manejo de tokens en frontend requiere cuidado (usar cookie httpOnly para refresh).
#
# Mejoras:
# - Añadir testing con Vitest/RTL.
# - Internacionalización.
# - Mapa y filtros avanzados de bbox/ciudad.

# %%
# Imprimimos la arquietectura de la base de datos generada
print(result.database)
# Out:
# Motor: PostgreSQL 16.
#
# Esquema y relaciones (resumen):
# - users(id PK, email UNIQUE, hashed_password, full_name, is_active, created_at TIMESTAMPTZ)
# - roles(id PK, name UNIQUE)
# - user_roles(user_id FK->users, role_id FK->roles, PK compuesta)
# - refresh_tokens(id PK, user_id FK->users, token_hash UNIQUE, exp TIMESTAMPTZ, revoked BOOL)
# - incidents(id PK, title, description, occurred_at TIMESTAMPTZ, severity INT CHECK 1..5, lat NUMERIC(9,6), lon NUMERIC(9,6), city TEXT, status TEXT, created_by FK->users)
#
# Índices recomendados:
# - users(email)
# - incidents(occurred_at), incidents(city), incidents(severity)
# - Índice compuesto incidents(city, occurred_at DESC)
# - Índices en lat/lon si se filtra por bounding box (ej. BRIN para rango de lat/lon en datasets grandes)
#
# Migraciones:
# - Alembic con versionado, seeds iniciales (roles, admin).
#
# Ejemplo DDL (fragmento):
# CREATE TABLE incidents (
#   id BIGSERIAL PRIMARY KEY,
#   title TEXT NOT NULL,
#   description TEXT,
#   occurred_at TIMESTAMPTZ NOT NULL,
#   severity SMALLINT NOT NULL CHECK (severity BETWEEN 1 AND 5),
#   lat NUMERIC(9,6) NOT NULL,
#   lon NUMERIC(9,6) NOT NULL,
#   city TEXT,
#   status TEXT DEFAULT 'open',
#   created_by BIGINT REFERENCES users(id)
# );
# CREATE INDEX idx_incidents_city_date ON incidents(city, occurred_at DESC);
#
# Analítica básica en SQL (ejemplos):
# - Resumen por día: SELECT date_trunc('day', occurred_at) d, count(*) FROM incidents WHERE occurred_at BETWEEN $1 AND $2 GROUP BY d ORDER BY d;
# - Por severidad: SELECT severity, count(*) FROM incidents WHERE occurred_at BETWEEN $1 AND $2 GROUP BY severity ORDER BY severity;
#
# Pros:
# - Postgres cubre bien CRUD y agregaciones.
# - Alembic asegura reproducibilidad de esquema.
#
# Contras:
# - Sin PostGIS, consultas geoespaciales avanzadas son limitadas.
#
# Mejoras:
# - Activar PostGIS si se requieren queries espaciales (buffers, within, heatmaps).

# %%
# Imprimimos la contenerizacion generada
print(result.container)
# Out:
# Objetivo: Desarrollo local simple con Docker Compose.
#
# Servicios:
# - db: postgres:16 con volumen persistente.
# - backend: imagen construida desde backend/ con Uvicorn.
# - frontend: build de React y servido con Nginx.
#
# docker-compose.yml (ejemplo mínimo):
# version: '3.9'
# services:
#   db:
#     image: postgres:16
#     environment:
#       - POSTGRES_USER=app
#       - POSTGRES_PASSWORD=app
#       - POSTGRES_DB=appdb
#     ports:
#       - '5432:5432'
#     volumes:
#       - db-data:/var/lib/postgresql/data
#     healthcheck:
#       test: ['CMD-SHELL', 'pg_isready -U app -d appdb']
#       interval: 10s
#       timeout: 5s
#       retries: 5
#   backend:
#     build: ./backend
#     environment:
#       - DATABASE_URL=postgresql+psycopg://app:app@db:5432/appdb
#       - JWT_SECRET=change-me
#       - JWT_REFRESH_SECRET=change-me-too
#       - CORS_ORIGINS=http://localhost:5173
#     ports:
#       - '8000:8000'
#     depends_on:
#       db:
#         condition: service_healthy
#   frontend:
#     build:
#       context: ./frontend
#       dockerfile: Dockerfile
#     ports:
#       - '5173:80'
#     depends_on:
#       - backend
# volumes:
#   db-data:
#
# Dockerfile backend (ejemplo):
# FROM python:3.12-slim
# WORKDIR /app
# COPY backend/pyproject.toml backend/poetry.lock* ./
# RUN pip install --no-cache-dir -U pip && pip install --no-cache-dir fastapi uvicorn[standard] sqlalchemy psycopg[binary] alembic pydantic passlib[argon2] PyJWT python-multipart
# COPY backend/app ./app
# EXPOSE 8000
# CMD ['uvicorn', 'app.main:app', '--host', '0.0.0.0', '--port', '8000']
#
# Dockerfile frontend (ejemplo Nginx):
# # build
# FROM node:20-alpine AS build
# WORKDIR /app
# COPY frontend/package*.json ./
# RUN npm ci
# COPY frontend/ ./
# RUN npm run build
# # serve
# FROM nginx:alpine
# COPY --from=build /app/dist /usr/share/nginx/html
# COPY deploy/nginx/default.conf /etc/nginx/conf.d/default.conf
# EXPOSE 80
#
# Pros:
# - Levanta todo con un solo comando (docker compose up -d).
# - Aislamiento por servicio y redes internas.
#
# Contras:
# - No incluye TLS ni proxy inverso en esta versión básica.
# - Logs solo en stdout; no hay agregación.
#
# Mejoras:
# - Añadir Traefik/Nginx reverse-proxy con TLS y rutas.
# - Variables de entorno gestionadas con secrets.
# - Healthchecks para backend y frontend y restart policies.

# %% [markdown]
# ## Agregamos una segunda configuracion para el frontend con Streamlit y la base de datos con SQLite

# %%
# Establecemos las inputs para el prompt
inputs2 = {
    "objetivo": "Crear la arquitectura de la app para la gestion de un sistema CRUD completo.",
    "requisitos": """Crear la arquitectura de la app para la gestion de un sistema CRUD que:
        - Incluya los siguientes componentes: backend, frontend, base de datos y contenerizacion basica.
        - Implemente funcionalidades core de autneticación, gestion de usuarios, y una caracteristica de analisis urbano
        como accidentes o inicidentes de trafico.
        - Defina una arquitectura simplificada pero funcional.""",
    "especificaciones": """
    - Debe de usar API Rest para el backend.
    - Debe usar SQlite como base de datos.
    - Debe usar Streamlit para la creación del frontend.
    - Debe de tener una arquitectura simplificada pero funcional.
    - Debe de incluir ejemplos de la arquitectura.
    - Debe de describir el proceso de diseño en pasos enumerados.
    - Debe de incluir los puntos a favor y en contra de la arquitectura seleccionada.
    - Debe de incluir los puntos de mejora de la arquitectura seleccionada.""",
    "format_instructions": parser.get_format_instructions()
}

# %%
# Ejecutamos el pipeline
result2 = chain.invoke(inputs2)

# %%
print(result2.estructura)
# Out:
# Resumen general:
# - Monorepo con cuatro piezas: backend (API REST en FastAPI), frontend (Streamlit), base de datos (SQLite embebida) y contenerización básica (Docker + Docker Compose).
# - Flujo: Usuario en Streamlit -> HTTP/JSON -> FastAPI -> SQLAlchemy -> archivo SQLite.
# - Entidades principales: Usuario (autenticación y gestión), Incidente (accidentes/incidentes urbanos), Token JWT (acceso/refresh).
#
# Estructura de carpetas propuesta:
# - /app
#   - /backend
#     - /src
#       - main.py
#       - /api (routers)
#       - /core (config, seguridad)
#       - /models (SQLAlchemy)
#       - /schemas (Pydantic)
#       - /services (lógica)
#       - /repositories (DAO)
#       - /tests
#     - requirements.txt
#     - Dockerfile
#   - /frontend
#     - app.py
#     - /pages (múltiples pantallas Streamlit)
#     - api_client.py
#     - Dockerfile
#     - requirements.txt
#   - /data
#     - app.db (SQLite; montado como volumen)
#   - docker-compose.yml
#   - .env
#
# Flujo de datos (simplificado):
# 1) Streamlit autentica al usuario con email/contraseña contra /auth/login y guarda el JWT en session_state.
# 2) Las pantallas de gestión llaman a /users y /incidents con el token en Authorization: Bearer.
# 3) Las consultas de analítica consumen /analytics/* que ejecutan agregaciones SQL sobre SQLite.
#
# Proceso de diseño (pasos enumerados):
# 1) Modelado de dominio: identificar entidades Usuario e Incidente; definir relaciones y restricciones (email único, FK created_by).
# 2) Definir contratos REST: rutas, métodos, esquemas Pydantic para request/response, paginación y filtros.
# 3) Seguridad: elegir JWT (HS256), hashing de contraseñas (bcrypt), CORS y autorizaciones por rol.
# 4) Persistencia: SQLAlchemy con SQLite; creación automática de tablas al iniciar; índices mínimos para consultas frecuentes.
# 5) Frontend: páginas Streamlit desacopladas, cliente HTTP centralizado, manejo de sesión y protección de páginas.
# 6) Contenerización: dos imágenes ligeras (backend y frontend), volumen para /data/app.db; Compose con red interna.
# 7) Observabilidad básica: logs estructurados y salud /health.
# 8) Pruebas: unitarias para servicios y de integración para endpoints críticos.
#
# Ejemplos de endpoints clave:
# - Autenticación: POST /auth/register, POST /auth/login, POST /auth/refresh, GET /auth/me
# - Usuarios: GET/POST /users, GET/PATCH/DELETE /users/{id}
# - Incidentes: GET/POST /incidents, GET/PATCH/DELETE /incidents/{id}
# - Analítica: GET /analytics/summary?from=...&to=..., GET /analytics/heatmap?grid=...
#
# Pros de la arquitectura:
# - Sencilla y rápida de levantar (SQLite + FastAPI + Streamlit).
# - Acoplamiento bajo entre frontend y backend vía REST.
# - Coste operativo mínimo; ideal para POC y MVP.
# - Docker Compose facilita entornos reproducibles.
#
# Contras de la arquitectura:
# - SQLite limita concurrencia de escritura y features avanzadas (sin geoespacial nativo).
# - Streamlit no es un framework de SPA completo; limitado para UI muy complejas.
# - Ausencia de migraciones formales complica cambios de esquema si crece el sistema.
# - Analítica intensiva puede requerir optimizaciones o cache.

# %%
print(result2.backend)
# Out:
# Tecnologías: Python 3.11, FastAPI, Uvicorn, SQLAlchemy 2.x, Pydantic v2, Passlib[bcrypt], PyJWT, httpx/requests para tests, SlowAPI (opcional) para rate limiting.
#
# Estructura lógica:
# - api/routers: auth.py, users.py, incidents.py, analytics.py, health.py
# - services/: auth_service.py, user_service.py, incident_service.py, analytics_service.py
# - repositories/: user_repo.py, incident_repo.py
# - models/: user.py, incident.py, base.py
# - schemas/: user.py, incident.py, auth.py
# - core/: config.py, security.py, db.py (SessionLocal), deps.py (Depends), logging.py
#
# Configuración (.env):
# - APP_ENV=dev
# - SECRET_KEY=clave_super_secreta
# - ACCESS_TOKEN_EXPIRE_MINUTES=15
# - REFRESH_TOKEN_EXPIRE_DAYS=7
# - DATABASE_URL=sqlite:///data/app.db
# - CORS_ORIGINS=http://localhost:8501
#
# main.py (esqueleto):
# from fastapi import FastAPI
# from fastapi.middleware.cors import CORSMiddleware
# from core.config import settings
# from core.db import init_db
# from api import auth, users, incidents, analytics, health
#
# app = FastAPI(title='Urban Incidents API')
# app.add_middleware(CORSMiddleware, allow_origins=settings.cors_origins, allow_credentials=True, allow_methods=['*'], allow_headers=['*'])
# app.include_router(health.router)
# app.include_router(auth.router, prefix='/auth', tags=['auth'])
# app.include_router(users.router, prefix='/users', tags=['users'])
# app.include_router(incidents.router, prefix='/incidents', tags=['incidents'])
# app.include_router(analytics.router, prefix='/analytics', tags=['analytics'])
#
# @app.on_event('startup')
# async def startup():
#     init_db()
#
# core/db.py (sqlite + create_all):
# from sqlalchemy import create_engine
# from sqlalchemy.orm import sessionmaker
# from models.base import Base
# from core.config import settings
# engine = create_engine(settings.database_url, connect_args={'check_same_thread': False})
# SessionLocal = sessionmaker(bind=engine, autocommit=False, autoflush=False)
# def init_db():
#     Base.metadata.create_all(bind=engine)
#
# models/user.py (resumen):
# from sqlalchemy import Column, Integer, String, DateTime, func
# from sqlalchemy.orm import relationship
# from .base import Base
# class User(Base):
#     __tablename__ = 'users'
#     id = Column(Integer, primary_key=True)
#     email = Column(String, unique=True, index=True, nullable=False)
#     hashed_password = Column(String, nullable=False)
#     full_name = Column(String)
#     role = Column(String, default='user')
#     created_at = Column(DateTime, server_default=func.now())
#
# models/incident.py (resumen):
# from sqlalchemy import Column, Integer, String, Float, DateTime, ForeignKey, Index
# from sqlalchemy.orm import relationship
# from .base import Base
# class Incident(Base):
#     __tablename__ = 'incidents'
#     id = Column(Integer, primary_key=True)
#     title = Column(String, nullable=False)
#     description = Column(String)
#     severity = Column(Integer, index=True)
#     lat = Column(Float, index=True)
#     lon = Column(Float, index=True)
#     happened_at = Column(DateTime, index=True)
#     created_by = Column(Integer, ForeignKey('users.id'))
#     Index('ix_incidents_time_severity', happened_at, severity)
#
# security JWT (núcleo):
# from datetime import datetime, timedelta
# import jwt
# from passlib.context import CryptContext
# pwd_ctx = CryptContext(schemes=['bcrypt'], deprecated='auto')
# def hash_password(p): return pwd_ctx.hash(p)
# def verify_password(p, h): return pwd_ctx.verify(p, h)
# def create_token(sub, expires_minutes, secret, algorithm='HS256', token_type='access'):
#     now = datetime.utcnow()
#     payload = {'sub': str(sub), 'type': token_type, 'iat': now, 'exp': now + timedelta(minutes=expires_minutes)}
#     return jwt.encode(payload, secret, algorithm=algorithm)
#
# api/auth.py (extracto):
# from fastapi import APIRouter, Depends, HTTPException
# from sqlalchemy.orm import Session
# from core.deps import get_db, get_current_user
# from services.auth_service import register, login, me
# router = APIRouter()
# @router.post('/register')
# def register_user(payload: dict, db: Session = Depends(get_db)):
#     return register(db, payload)
# @router.post('/login')
# def login_user(payload: dict, db: Session = Depends(get_db)):
#     return login(db, payload['email'], payload['password'])
# @router.get('/me')
# def get_me(user=Depends(get_current_user)):
#     return me(user)
#
# api/incidents.py (extracto CRUD):
# from fastapi import APIRouter, Depends
# from sqlalchemy.orm import Session
# from core.deps import get_db, get_current_user
# router = APIRouter()
# @router.get('')
# def list_incidents(limit: int = 50, offset: int = 0, db: Session = Depends(get_db)):
#     ...
# @router.post('')
# def create_incident(payload: dict, db: Session = Depends(get_db), user=Depends(get_current_user)):
#     ...
#
# api/analytics.py (agregaciones):
# @router.get('/summary')
# def summary(from_: str | None = None, to: str | None = None, db: Session = Depends(get_db)):
#     # SELECT severity, COUNT(*) FROM incidents WHERE happened_at BETWEEN ... GROUP BY severity
#     ...
# @router.get('/heatmap')
# def heatmap(grid: float = 0.01, db: Session = Depends(get_db)):
#     # Agrupar por celdas discretizadas: round(lat/grid), round(lon/grid)
#     ...
#
# Buenas prácticas incluidas:
# - Validación con Pydantic, respuestas tipadas, manejo centralizado de errores.
# - Autorización básica por rol para endpoints de administración.
# - Paginación, filtros (fecha, severidad) y ordenamiento.
# - Rate limit opcional con SlowAPI para /auth/*.
# - Logs estructurados y endpoint /health.

# %%
print(result2.frontend)
# Out:
# Tecnología: Streamlit en modo multipágina. Se consume la API REST con requests/httpx. Gestión de sesión con st.session_state para token JWT.
#
# Estructura:
# - app.py (layout, routing ligero, verificación de sesión)
# - pages/
#   - 01_Login.py
#   - 02_Usuarios.py
#   - 03_Incidentes.py
#   - 04_Analitica.py
# - api_client.py (cliente HTTP con manejo de token y base URL)
#
# api_client.py (extracto):
# import os, requests, streamlit as st
# API_BASE = os.getenv('API_BASE_URL', 'http://localhost:8000')
# class API:
#     def __init__(self):
#         self.base = API_BASE
#     def headers(self):
#         token = st.session_state.get('token')
#         return {'Authorization': f'Bearer {token}'} if token else {}
#     def login(self, email, password):
#         r = requests.post(f'{self.base}/auth/login', json={'email': email, 'password': password})
#         r.raise_for_status(); return r.json()
#     def get(self, path, params=None):
#         r = requests.get(f'{self.base}{path}', params=params, headers=self.headers()); r.raise_for_status(); return r.json()
#     def post(self, path, data):
#         r = requests.post(f'{self.base}{path}', json=data, headers=self.headers()); r.raise_for_status(); return r.json()
# api = API()
#
# 01_Login.py (extracto):
# import streamlit as st
# from api_client import api
# st.title('Iniciar sesión')
# email = st.text_input('Email')
# password = st.text_input('Contraseña', type='password')
# if st.button('Entrar'):
#     try:
#         data = api.login(email, password)
#         st.session_state['token'] = data.get('access_token')
#         st.success('Autenticado')
#         st.switch_page('pages/03_Incidentes.py')
#     except Exception as e:
#         st.error('Credenciales inválidas')
#
# 03_Incidentes.py (extracto):
# import streamlit as st
# from api_client import api
# if 'token' not in st.session_state: st.stop()
# st.title('Incidentes')
# col1, col2 = st.columns(2)
# with col1:
#     severity = st.selectbox('Severidad', [1,2,3,4,5])
#     title = st.text_input('Título')
# with col2:
#     lat = st.number_input('Lat', format='%f')
#     lon = st.number_input('Lon', format='%f')
#     happened_at = st.date_input('Fecha')
# if st.button('Crear'):
#     api.post('/incidents', {'title': title, 'severity': severity, 'lat': lat, 'lon': lon, 'happened_at': str(happened_at)})
#     st.success('Creado')
# items = api.get('/incidents', params={'limit': 20})
# st.dataframe(items)
#
# 04_Analitica.py (extracto):
# import streamlit as st
# from api_client import api
# st.title('Analítica de incidentes')
# summary = api.get('/analytics/summary')
# st.json(summary)
#
# Notas de seguridad y UX:
# - Sanitizar entradas y validar en backend; mostrar errores amigables.
# - Refrescar token si expira (opcional: endpoint /auth/refresh y almacenamiento de refresh token en cookie httpOnly si se requiere).

# %%
print(result2.database)
# Out:
# SQLite embebido, archivo en /data/app.db (montado como volumen). URL: sqlite:///data/app.db.
#
# Esquema:
# - users(id PK, email UNIQUE, hashed_password, full_name, role, created_at)
# - incidents(id PK, title, description, severity, lat, lon, happened_at, created_by FK users.id)
#
# Índices sugeridos:
# - users.email (único)
# - incidents.severity, incidents.happened_at, incidents.lat, incidents.lon
# - Índice compuesto ix_incidents_time_severity(happened_at, severity) para analítica temporal por severidad
#
# Relaciones:
# - incidents.created_by -> users.id
#
# Creación de tablas:
# - Base.metadata.create_all(bind=engine) en startup para simplicidad.
#
# Migraciones:
# - En MVP, cambios manuales controlados. Para crecer, incorporar Alembic para versiones de schema.
#
# Semillas de datos:
# - Script seed.py que inserta un admin y algunos incidentes aleatorios para pruebas.
#
# Consideraciones de concurrencia:
# - SQLite soporta múltiples lectores y un escritor; operaciones de escritura deben ser cortas.
#
# Backups:
# - Copia periódica del archivo /data/app.db (hot backups con .backup).
